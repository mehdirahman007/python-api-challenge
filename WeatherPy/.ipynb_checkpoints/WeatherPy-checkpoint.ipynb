# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
index_counter = 0
set_counter = 1



print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : thompson
# Processing Record 2 of Set 1 : santa barbara
# Processing Record 3 of Set 1 : cape town
# Processing Record 4 of Set 1 : sai buri
# Processing Record 5 of Set 1 : benalla
# Processing Record 6 of Set 1 : pisco
# City not found. Skipping...
# Processing Record 7 of Set 1 : puerto ayora
# Processing Record 8 of Set 1 : broome
# Processing Record 9 of Set 1 : hermanus
# Processing Record 10 of Set 1 : goma
# Processing Record 11 of Set 1 : walvis bay
# Processing Record 12 of Set 1 : kodiak
# Processing Record 13 of Set 1 : busselton
# Processing Record 14 of Set 1 : east london
# Processing Record 15 of Set 1 : longyearbyen
# Processing Record 16 of Set 1 : esperance
# Processing Record 17 of Set 1 : kavieng
# Processing Record 18 of Set 1 : ushuaia
# Processing Record 19 of Set 1 : katsuura
# Processing Record 20 of Set 1 : rikitea
# Processing Record 21 of Set 1 : yellowknife
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({ 
                "City" : city_name,
                "Cloudiness" : cloudiness,
                "Country" : country,
                "Date" : date,
                "Humidity" : humidity,
                "Lat" : lat,
                "Lng" : lng,
                "Max Temp" : max_temp,
                "Wind Speed" : wind_speed
})
weather_df
# Out:
#               City  Cloudiness Country        Date  Humidity      Lat  \
# 0         Thompson          40      CA  1627396845        63  55.7435
# 1    Santa Barbara          90      US  1627396845        94  34.7333
# 2        Cape Town          75      ZA  1627396845        57 -33.9258
# 3         Sai Buri          45      TH  1627396846        78   6.7013
# 4          Benalla         100      AU  1627396846        52 -36.5500
# ..             ...         ...     ...         ...       ...      ...
# 547         Helena           1      US  1627396995        33  46.5927
# 548       La Unión          75      PE  1627396995        63  -5.4000
# 549       Were Īlu          98      ET  1627396996        84  10.6000
# 550        Cañazas          72      PA  1627396996        72   8.3167
# 551     Mahibadhoo         100      MV  1627396996        75   3.7833
#
#           Lng  Max Temp  Wind Speed
# 0    -97.8558     64.56        5.75
# 1   -120.0343     69.35        0.00
# ...

# %%
weather_df.to_csv("output_data/cities.csv", index = False)

# %%
weather_df.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  552.000000  5.520000e+02  552.000000  552.000000  552.000000
# mean    53.355072  1.627397e+09   66.682971   20.963720   19.200923
# std     38.841724  7.168296e+01   22.991181   33.308122   92.090161
# min      0.000000  1.627396e+09    7.000000  -54.800000 -179.166700
# 25%     10.000000  1.627397e+09   54.000000   -6.846650  -63.794725
# 50%     59.500000  1.627397e+09   72.000000   26.340200   24.356050
# 75%     91.250000  1.627397e+09   83.000000   49.212500  101.335850
# max    100.000000  1.627397e+09  100.000000   78.218600  179.316700
#
#          Max Temp  Wind Speed
# count  552.000000  552.000000
# mean    71.627120    8.250471
# std     15.148232    5.850589
# min     31.750000    0.000000
# 25%     60.572500    3.542500
# 50%     74.920000    6.970000
# 75%     82.080000   11.552500
# max    115.250000   35.930000

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], facecolor = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Max Temperature (07/27/21)")

plt.xlabel("Laitude")

plt.ylabel("Max Temperature (F)")

plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolor = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Humidity (07/27/21)")

plt.xlabel("Laitude")

plt.ylabel("Humidity (%)")

plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Cloudiness (07/27/21)")

plt.xlabel("Laitude")

plt.ylabel("Cloudiness (%)")

plt.ylim(-5,105)

plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolor = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Wind Speed (mph) (07/27/21)")

plt.xlabel("Laitude")

plt.ylabel("Wind Speed (%)")

plt.ylim(-2,50)

plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
n_hem = weather_df.loc[weather_df["Lat"] >= 0]
s_hem = weather_df.loc[weather_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
n_hem.plot(kind='scatter', x='Lat', y='Max Temp', title='Latitude vs. Max Temperature')

(slope, intercept, rvalue, pvalue, stderr) = linregress(n_hem['Lat'], n_hem['Max Temp'])
regression = n_hem['Lat'] * slope + intercept
equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(n_hem['Lat'], n_hem['Max Temp'])
plt.plot(n_hem['Lat'],regression,"r-")
plt.annotate(equation, (0, 35),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {equation}')
# Out:
# The r-squared is 0.40209724331418406
# The linear regression model is y = -0.49x + 92.77

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s_hem.plot(kind='scatter', x='Lat', y='Max Temp', title='Latitude vs. Max Temperature')

(slope, intercept, rvalue, pvalue, stderr) = linregress(s_hem['Lat'], s_hem['Max Temp'])
regression = s_hem['Lat'] * slope + intercept
equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(s_hem['Lat'], s_hem['Max Temp'])
plt.plot(s_hem['Lat'],regression,"r-")
plt.annotate(equation, (-25, 30),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {equation}')
# Out:
# The r-squared is 0.6702438512774045
# The linear regression model is y = 0.85x + 85.26

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
n_hem.plot(kind='scatter', x='Lat', y='Humidity', title='Latitude vs. Humidity')

(slope, intercept, rvalue, pvalue, stderr) = linregress(n_hem['Lat'], n_hem['Humidity'])
regression = n_hem['Lat'] * slope + intercept
equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(n_hem['Lat'], n_hem['Humidity'])
plt.plot(n_hem['Lat'],regression,"r-")
plt.annotate(equation, (48, 10),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {equation}')
# Out:
# The r-squared is 0.01014330049395787
# The linear regression model is y = 0.12x + 63.29

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s_hem.plot(kind='scatter', x='Lat', y='Humidity', title='Latitude vs. Humidity')

(slope, intercept, rvalue, pvalue, stderr) = linregress(s_hem['Lat'], s_hem['Humidity'])
regression = s_hem['Lat'] * slope + intercept
equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(s_hem['Lat'], s_hem['Humidity'])
plt.plot(s_hem['Lat'],regression,"r-")
plt.annotate(equation, (-55, 10),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {equation}')
# Out:
# The r-squared is 0.000864548801749394
# The linear regression model is y = -0.05x + 62.74

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_hem.plot(kind='scatter', x='Lat', y='Cloudiness', title='Latitude vs. Cloudiness')

(slope, intercept, rvalue, pvalue, stderr) = linregress(n_hem['Lat'], n_hem['Cloudiness'])
regression = n_hem['Lat'] * slope + intercept
equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(n_hem['Lat'], n_hem['Cloudiness'])
plt.plot(n_hem['Lat'],regression,"r-")
plt.annotate(equation, (48, 10),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {equation}')
# Out:
# The r-squared is 0.002096485300022466
# The linear regression model is y = -0.09x + 61.36

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_hem.plot(kind='scatter', x='Lat', y='Cloudiness', title='Latitude vs. Cloudiness')

(slope, intercept, rvalue, pvalue, stderr) = linregress(s_hem['Lat'], s_hem['Cloudiness'])
regression = s_hem['Lat'] * slope + intercept
equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(s_hem['Lat'], s_hem['Cloudiness'])
plt.plot(s_hem['Lat'],regression,"r-")
plt.annotate(equation, (-55, 10),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {equation}')
# Out:
# The r-squared is 0.006239703698745669
# The linear regression model is y = -0.21x + 38.37

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
n_hem.plot(kind='scatter', x='Lat', y='Wind Speed', title='Latitude vs. Wind Speed')

(slope, intercept, rvalue, pvalue, stderr) = linregress(n_hem['Lat'], n_hem['Wind Speed'])
regression = n_hem['Lat'] * slope + intercept
equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(n_hem['Lat'], n_hem['Wind Speed'])
plt.plot(n_hem['Lat'],regression,"r-")
plt.annotate(equation, (50, 30),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {equation}')
# Out:
# The r-squared is 0.008575497876800588
# The linear regression model is y = -0.03x + 8.83

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_hem.plot(kind='scatter', x='Lat', y='Wind Speed', title='Latitude vs. Wind Speed')

(slope, intercept, rvalue, pvalue, stderr) = linregress(s_hem['Lat'], s_hem['Wind Speed'])
regression = s_hem['Lat'] * slope + intercept
equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(s_hem['Lat'], s_hem['Wind Speed'])
plt.plot(s_hem['Lat'],regression,"r-")
plt.annotate(equation, (-20, 25),fontsize=14,color="red")

print(f'The r-squared is {rvalue**2}')
print(f'The linear regression model is {equation}')
# Out:
# The r-squared is 0.04811958874187438
# The linear regression model is y = -0.1x + 7.1

# %%
# Out:
# The r-value is: 0.017128274759839232
